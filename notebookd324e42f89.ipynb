# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/tabular-playground-series-may-2022/sample_submission.csv
# /kaggle/input/tabular-playground-series-may-2022/train.csv
# /kaggle/input/tabular-playground-series-may-2022/test.csv

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.stats import loguniform
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.preprocessing import OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import log_loss
from sklearn.model_selection import cross_validate, train_test_split
from sklearn import set_config
set_config(display='diagram')

# %% [markdown]
# Assume KFold cross_validation is valid

# %%
train_data = pd.read_csv(
    "/kaggle/input/tabular-playground-series-may-2022/train.csv",
)
train_target = train_data.target.copy()
train_data.drop(columns=["id", "target"], inplace=True)

# %%
print(train_data.f_27[0])
print(train_data.f_27.nunique())
# Out:
# ABABDADBAB
# 741354

# %%
new_features = pd.DataFrame(
    np.concatenate(
        train_data.f_27.apply(lambda x: [sym for sym in x]).values, axis=0
    ).reshape(-1, 10),
    columns = [f"f_27_{x}" for x in range(10)]
)

# %%
train_data = pd.concat(([train_data, new_features]), axis=1)
train_data.drop(columns="f_27", inplace=True)

# %%
cat_processor = OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=np.nan)
preprocessor = ColumnTransformer(
    [("OrdinalEncoder", cat_processor, [f"f_27_{x}" for x in range(10)])],
    remainder="passthrough"
)
estimator = HistGradientBoostingClassifier()

model = make_pipeline(preprocessor, estimator)

# %%
# cv_results = cross_validate(
#     model, train_data, train_target, scoring=["accuracy", "neg_log_loss"],
#     return_train_score=True,cv=5, n_jobs=3, verbose=2
# )

# %%
# cv_results = pd.DataFrame(cv_results)
# cv_results

# %% [markdown]
# Found with random search:
#
# | l2_regularization | learning_rate | max_leaf_nodes | min_samples_leaf | mean_test_score | std_test_score |
# | ----------- | ----------- | ----------- | ----------- | ----------- | ----------- |
# | 0.244505 | 0.182073 | 98 | 29 | 0.900514 | 0.000727 |

# %%
def feed_batch(df, size=10000):
    for i in range(0, df.shape[0], size):
        try:
            batch = df.iloc[i : i + size].copy()
        except:
            batch = df.iloc[i:].copy()
        yield batch

# %%
data_generator = feed_batch(train_data[-20000:])
target_generator = feed_batch(train_target[-20000:])

# %%
try:
    test_batch_data = next(data_generator)
    test_batch_target = next(target_generator)
    model.fit(test_batch_data[:7500], test_batch_target[:7500])
    model.score(test_batch_data[7500:], test_batch_target[7500:])
except StopIteration:
    print("Ops")

# %%
(test_batch_target[:7500] == model.predict(test_batch_data[:7500])).value_counts()
# Out:
# True     6885
# False     615
# Name: target, dtype: int64

# %%
log_loss(test_batch_target[7500:], model.predict(test_batch_data[7500:]))
# Out:
# 6.49335488955454

# %%
print(loguniform.cdf(50,1,100))  # current procentile
print(loguniform.ppf(.80,1,100))  # 80th procentile value
print(loguniform.cdf(39.810717055349734,1,100))
# Out:
# 0.8494850021680093
# 39.810717055349734
# 0.7999999999999999

# %%
def update_int_param(cur_val, min_val=2, max_val=256, by=1):
    # ensure return is int and within the interval
    new_val = max([round(cur_val + by), min_val])
    return min([new_val, max_val])

def update_log_param(cur_val, min_val=1e-3, max_val=1e3, by=0.001):
    cur_p = loguniform.cdf(cur_val, min_val, max_val)
    if (cur_p < 0) | (cur_p > 1):
        return cur_val
    return loguniform.ppf(cur_p + by, min_val, max_val)

# %%
model.set_params(**{"histgradientboostingclassifier__l2_regularization":1e-3})
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('OrdinalEncoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=nan),
#                                                   ['f_27_0', 'f_27_1', 'f_27_2',
#                                                    'f_27_3', 'f_27_4', 'f_27_5',
#                                                    'f_27_6', 'f_27_7', 'f_27_8',
#                                                    'f_27_9'])])),
#                 ('histgradientboostingclassifier',
#                  HistGradientBoostingClassifier(l2_regularization=0.001))])

# %%
param_update_funcs = {
    'histgradientboostingclassifier__l2_regularization': update_log_param,
    'histgradientboostingclassifier__learning_rate': update_log_param,
    'histgradientboostingclassifier__max_leaf_nodes': update_int_param,
    'histgradientboostingclassifier__min_samples_leaf': update_int_param,
}

# %%
pd.DataFrame({key: [model.get_params()[key ]] for key in param_update_funcs.keys()})
# Out:
#    histgradientboostingclassifier__l2_regularization  \
# 0                                              0.001
#
#    histgradientboostingclassifier__learning_rate  \
# 0                                            0.1
#
#    histgradientboostingclassifier__max_leaf_nodes  \
# 0                                              31
#
#    histgradientboostingclassifier__min_samples_leaf
# 0                                                20

# %%
def batch_train(
    model, batch_data, batch_target, param_update_funcs
):
    # data split, initial fit and score
    X_train, X_test, y_train, y_test = train_test_split(batch_data, batch_target)
    model.fit(X_train, y_train)
    loss = log_loss(y_test, model.predict(X_test))

    # initiate log
    params_log = np.array(
        [[model.get_params()[key] for key in param_update_funcs.keys()]])
    loss_log = [loss]

    # forward pass
    for param, update_func in param_update_funcs.items():
        cur_val = model.get_params()[param]
        new_val = update_func(cur_val)  # "step" increase
        model.set_params(**{param: new_val})
        model.fit(X_train, y_train)
        loss = log_loss(y_test, model.predict(X_test))

        # log entry
        params_log = np.append(
            params_log,
            np.array(
                [[model.get_params()[key] for key in param_update_funcs.keys()]]),
            axis=0)
        loss_log.append(loss)

        # return to the original parameter value
        model.set_params(**{param: cur_val})
    
    log = pd.DataFrame(params_log, columns=param_update_funcs.keys())
    log["test_loss"] = loss_log

    return log

# %%
log = batch_train(model, test_batch_data, test_batch_target, param_update_funcs)
log.rename(columns={item:item.split("__")[-1] for item in log.columns})
# Out:
#    l2_regularization  learning_rate  max_leaf_nodes  min_samples_leaf  \
# 0           0.001000       0.100000            31.0              20.0
# 1           0.001014       0.100000            31.0              20.0
# 2           0.001000       0.101391            31.0              20.0
# 3           0.001000       0.100000            32.0              20.0
# 4           0.001000       0.100000            31.0              21.0
#
#    test_loss
# 0   6.037437
# 1   6.037437
# 2   5.871651
# 3   5.857834
# 4   6.051253

# %%
def update_params(log):
    d_losses = log["test_loss"][1:] - log["test_loss"][0]
    new_params = {}
    for i, dl in enumerate(d_losses):
        if np.allclose(0, dl):
            continue  # go to next iteration
        elif dl < 0:
            new_params[log.iloc[:, i].name] = \
            log.iloc[:, i][0] + log.iloc[:, i].diff().max()
        else:
            new_params[log.iloc[:, i].name] = \
            log.iloc[:, i][0] - log.iloc[:, i].diff().max()
    return new_params

# %%
new_params = update_params(log)
new_params
# Out:
# {'histgradientboostingclassifier__learning_rate': 0.101391138573668,
#  'histgradientboostingclassifier__max_leaf_nodes': 32.0,
#  'histgradientboostingclassifier__min_samples_leaf': 19.0}

# %%
def train_epoch(model, data, target, param_update_funcs,
                batch_size=50_000, verbose=None):
    """"""
    params_log = np.array(
        [[model.get_params()[key] for key in param_update_funcs.keys()]])
    loss_log, acc_log = [], []

    data_generator = feed_batch(data, size=batch_size)
    target_generator = feed_batch(target, size=batch_size)

    for batch_idx, (batch_data, batch_target) in enumerate(
        zip(data_generator, target_generator)):
        batch_log = batch_train(model, batch_data, batch_target, param_update_funcs)
        updated_params = update_params(batch_log)
        model.set_params(**updated_params)

        # get log entries
        X_train, X_test, y_train, y_test = train_test_split(batch_data, batch_target)
        model.fit(X_train, y_train)
        loss = log_loss(y_test, model.predict(X_test))
        acc = model.score(X_test, y_test)
    
        # log
        params_log = np.append(
            params_log,
            np.array(
                [[model.get_params()[key] for key in param_update_funcs.keys()]]),
            axis=0)
        loss_log.append(loss), acc_log.append(acc)

        if verbose:
            print(f"Batch {batch_idx}: test_loss: {loss:.4f}, test_accuracy: {acc:.4f}")
        
    total_log = pd.DataFrame(params_log[1:], columns=param_update_funcs.keys())
    total_log["test_loss"] = loss_log
    total_log["test_accuracy"] = acc_log
    return total_log
    # generate a batch
    # train on the batch - get log
    # use log to get new hyperparameters
    # set new hyperparameters

# %%
total_log = train_epoch(model,train_data, train_target, param_update_funcs,
                        batch_size=10_000, verbose=True)
# Out:
# Batch 0: test_loss: 5.8164, test_accuracy: 0.8316
# Batch 1: test_loss: 5.4157, test_accuracy: 0.8432
# Batch 2: test_loss: 6.2032, test_accuracy: 0.8204
# Batch 3: test_loss: 5.7888, test_accuracy: 0.8324
# Batch 4: test_loss: 6.4934, test_accuracy: 0.8120
# Batch 5: test_loss: 5.8716, test_accuracy: 0.8300
# Batch 6: test_loss: 5.8855, test_accuracy: 0.8296
# Batch 7: test_loss: 5.3467, test_accuracy: 0.8452
# Batch 8: test_loss: 5.7335, test_accuracy: 0.8340
# Batch 9: test_loss: 5.9822, test_accuracy: 0.8268
# Batch 10: test_loss: 5.9545, test_accuracy: 0.8276
# Batch 11: test_loss: 5.7749, test_accuracy: 0.8328
# Batch 12: test_loss: 5.9546, test_accuracy: 0.8276
# Batch 13: test_loss: 6.1756, test_accuracy: 0.8212
# Batch 14: test_loss: 5.6782, test_accuracy: 0.8356
# Batch 15: test_loss: 6.4381, test_accuracy: 0.8136
# Batch 16: test_loss: 6.2032, test_accuracy: 0.8204
# Batch 17: test_loss: 5.8440, test_accuracy: 0.8308
# Batch 18: test_loss: 5.7611, test_accuracy: 0.8332
# Batch 19: test_loss: 6.2585, test_accuracy: 0.8188
# Batch 20: test_loss: 5.8302, test_accuracy: 0.8312
# Batch 21: test_loss: 6.0374, test_accuracy: 0.8252
# Batch 22: test_loss: 6.1065, test_accuracy: 0.8232
# Batch 23: test_loss: 6.1480, test_accuracy: 0.8220
# Batch 24: test_loss: 6.0236, test_accuracy: 0.8256
# Batch 25: test_loss: 6.1480, test_accuracy: 0.8220
# Batch 26: test_loss: 6.0651, test_accuracy: 0.8244
# Batch 27: test_loss: 5.9269, test_accuracy: 0.8284
# Batch 28: test_loss: 5.9269, test_accuracy: 0.8284
# Batch 29: test_loss: 6.0651, test_accuracy: 0.8244
# Batch 30: test_loss: 6.1065, test_accuracy: 0.8232
# Batch 31: test_loss: 6.1756, test_accuracy: 0.8212
# Batch 32: test_loss: 6.2309, test_accuracy: 0.8196
# Batch 33: test_loss: 6.3690, test_accuracy: 0.8156
# Batch 34: test_loss: 6.0789, test_accuracy: 0.8240
# Batch 35: test_loss: 5.8026, test_accuracy: 0.8320
# Batch 36: test_loss: 6.1894, test_accuracy: 0.8208
# Batch 37: test_loss: 5.8578, test_accuracy: 0.8304
# Batch 38: test_loss: 6.1342, test_accuracy: 0.8224
# Batch 39: test_loss: 5.7335, test_accuracy: 0.8340
# Batch 40: test_loss: 6.2999, test_accuracy: 0.8176
# Batch 41: test_loss: 5.5953, test_accuracy: 0.8380
# Batch 42: test_loss: 6.1203, test_accuracy: 0.8228
# Batch 43: test_loss: 6.1065, test_accuracy: 0.8232
# Batch 44: test_loss: 6.3138, test_accuracy: 0.8172
# Batch 45: test_loss: 6.2861, test_accuracy: 0.8180
# Batch 46: test_loss: 6.0236, test_accuracy: 0.8256
# Batch 47: test_loss: 6.0789, test_accuracy: 0.8240
# Batch 48: test_loss: 6.0098, test_accuracy: 0.8260
# Batch 49: test_loss: 5.6230, test_accuracy: 0.8372
# Batch 50: test_loss: 5.8855, test_accuracy: 0.8296
# Batch 51: test_loss: 5.8164, test_accuracy: 0.8316
# Batch 52: test_loss: 6.2309, test_accuracy: 0.8196
# Batch 53: test_loss: 5.9269, test_accuracy: 0.8284
# Batch 54: test_loss: 6.5624, test_accuracy: 0.8100
# Batch 55: test_loss: 6.0236, test_accuracy: 0.8256
# Batch 56: test_loss: 5.6782, test_accuracy: 0.8356
# Batch 57: test_loss: 5.8993, test_accuracy: 0.8292
# Batch 58: test_loss: 6.2861, test_accuracy: 0.8180
# Batch 59: test_loss: 5.6506, test_accuracy: 0.8364
# Batch 60: test_loss: 6.0374, test_accuracy: 0.8252
# Batch 61: test_loss: 6.3552, test_accuracy: 0.8160
# Batch 62: test_loss: 6.6315, test_accuracy: 0.8080
# Batch 63: test_loss: 6.1756, test_accuracy: 0.8212
# Batch 64: test_loss: 5.8578, test_accuracy: 0.8304
# Batch 65: test_loss: 6.1894, test_accuracy: 0.8208
# Batch 66: test_loss: 5.3190, test_accuracy: 0.8460
# Batch 67: test_loss: 6.1203, test_accuracy: 0.8228
# Batch 68: test_loss: 5.8578, test_accuracy: 0.8304
# Batch 69: test_loss: 5.7335, test_accuracy: 0.8340
# Batch 70: test_loss: 6.5210, test_accuracy: 0.8112
# Batch 71: test_loss: 5.9545, test_accuracy: 0.8276
# Batch 72: test_loss: 6.3138, test_accuracy: 0.8172
# Batch 73: test_loss: 5.8164, test_accuracy: 0.8316
# Batch 74: test_loss: 6.4519, test_accuracy: 0.8132
# Batch 75: test_loss: 6.2447, test_accuracy: 0.8192
# Batch 76: test_loss: 6.4243, test_accuracy: 0.8140

# %%
total_log.rename(columns={item:item.split("__")[-1] for item in log.columns})
# Out:
#     l2_regularization  learning_rate  max_leaf_nodes  min_samples_leaf  \
# 0            0.001042       0.104070            38.0              21.0
# 1            0.001028       0.102623            37.0              22.0
# 2            0.001013       0.101195            36.0              21.0
# 3            0.001027       0.102603            37.0              22.0
# 4            0.001042       0.104030            38.0              21.0
# 5            0.001056       0.105477            37.0              22.0
# 6            0.001071       0.104010            36.0              21.0
# 7            0.001086       0.105457            37.0              22.0
# 8            0.001101       0.106924            38.0              23.0
# 9            0.001086       0.105437            37.0              22.0
# 10           0.001101       0.106903            38.0              23.0
# 11           0.001116       0.108391            39.0              24.0
# 12           0.001100       0.106883            40.0              23.0
# 13           0.001085       0.105396            39.0              22.0
# 14           0.001100       0.106862            38.0              21.0
# 15           0.001085       0.105375            37.0              20.0
# 16           0.001100       0.106841            36.0              19.0
# 17           0.001085       0.105355            37.0              20.0
#
#     test_loss  test_accuracy
# 0    4.990216        0.85552
# 1    5.034423        0.85424
# 2    4.970873        0.85608
# 3    5.042715        0.85400
# 4    4.929428        0.85728
# 5    4.946003        0.85680
# 6    4.760875        0.86216
# 7    4.965349        0.85624
# 8    4.879693        0.85872
# 9    4.807846        0.86080
# 10   5.051004        0.85376
# 11   4.769164        0.86192
# 12   4.807846        0.86080
# 13   4.962583        0.85632
# 14   4.887979        0.85848
# 15   4.965345        0.85624
# 16   4.945999        0.85680
# 17   5.125610        0.85160

# %%
[model.get_params()[key] for key in param_update_funcs.keys()]
# Out:
# [0.0010847447439617773, 0.10535498969018756, 37.0, 20.0]

# %%
model.fit(train_data[:37500], train_target[:37500])
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('OrdinalEncoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=nan),
#                                                   ['f_27_0', 'f_27_1', 'f_27_2',
#                                                    'f_27_3', 'f_27_4', 'f_27_5',
#                                                    'f_27_6', 'f_27_7', 'f_27_8',
#                                                    'f_27_9'])])),
#                 ('histgradientboostingclassifier',
#                  HistGradientBoostingClassifier(l2_regularization=0.0010847447439617773,
#                                                 learning_rate=0.10535498969018756,
#                                                 max_leaf_nodes=37.0,
#                                                 min_samples_leaf=20.0))])

# %%
model.score(train_data[37500:50000], train_target[37500:50000])
# Out:
# 0.85728

# %%
total_dummy_log = train_epoch(
    model,train_data, train_target,
    {key: lambda x:x for key in param_update_funcs.keys()}, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_33/3215170195.py in <module>
#       1 total_dummy_log = train_epoch(
#       2     model,train_data, train_target,
# ----> 3     {key: lambda x:x for key in param_update_funcs.keys()}, verbose=True)
#
# /tmp/ipykernel_33/3003711165.py in train_epoch(model, data, target, param_update_funcs, batch_size, verbose)
#      11     for batch_idx, (batch_data, batch_target) in enumerate(
#      12         zip(data_generator, target_generator)):
# ---> 13         batch_log = batch_train(model, batch_data, batch_target, param_update_funcs)
#      14         updated_params = update_params(batch_log)
#      15         model.set_params(**updated_params)
#
# /tmp/ipykernel_33/1680859890.py in batch_train(model, batch_data, batch_target, param_update_funcs)
#      17         new_val = update_func(cur_val)  # "step" increase
#      18         model.set_params(**{param: new_val})
# ---> 19         model.fit(X_train, y_train)
#      20         loss = log_loss(y_test, model.predict(X_test))
#      21
#
# /opt/conda/lib/python3.7/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     392             if self._final_estimator != "passthrough":
#     393                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 394                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     395
#     396         return self
#
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/_hist_gradient_boosting/gradient_boosting.py in fit(self, X, y, sample_weight)
#     524                     n_threads=n_threads,
#     525                 )
# --> 526                 grower.grow()
#     527
#     528                 acc_apply_split_time += grower.total_apply_split_time
#
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/_hist_gradient_boosting/grower.py in grow(self)
#     358         """Grow the tree, from root to leaves."""
#     359         while self.splittable_nodes:
# --> 360             self.split_next()
#     361
#     362         self._apply_shrinkage()
#
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/_hist_gradient_boosting/grower.py in split_next(self)
#     449             sample_indices_right,
#     450             right_child_pos,
# --> 451         ) = self.splitter.split_indices(node.split_info, node.sample_indices)
#     452         self.total_apply_split_time += time() - tic
#     453
#
# KeyboardInterrupt:
